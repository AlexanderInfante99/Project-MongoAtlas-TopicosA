# %% [markdown]
# # Update Documents and Collections

# %%
from connect import db
from pymongo import UpdateOne

modificar = db.libros

# Actualizar stock de un libro
res = modificar.update_one(
    {'Titulo': 'La ciudad Verde'},
    {'$inc':
        {'Stock': 10}
    }
)

for doc in modificar.find({'Titulo':'La ciudad Verde'}):
    print(doc)


print('Cambios', res.matched_count, 'Total', res.modified_count)
# Out:
# {'_id': ObjectId('690e11a57b0ea9143aec7d4d'), 'Titulo': 'La ciudad Verde', 'Autor': 'Mario Vargas Llosa', 'Anio': 1965, 'Categoria': ['Novela', 'Peruana'], 'Stock': 24}
# Cambios 1 Total 1

# %%
for doc in modificar.find({'Titulo':'La ciudad Verde'}):
    print(doc['Titulo'], 'hay', doc['Stock'], 'libros')
# Out:
# La ciudad Verde Hay 24 libros

# %%
# Actualizamos el stock actual
res = modificar.update_one(
    {'Titulo': 'La ciudad Verde'},
    {'$set':
        {'Stock': 10}
    }
)

# %%
for doc in modificar.find({'Titulo':'La ciudad Verde'}):
    print(doc['Titulo'], 'hay', doc['Stock'], 'libros')
# Out:
# La ciudad Verde hay 10 libros

# %%
#Actualizar usando Update_Many
res = modificar.update_many(
    {},
    {'$set':{
            'disponible': True
        }
    }
)
print('Cambios', res.matched_count, 'Total', res.modified_count)
# Out:
# Cambios 24 Total 0

# %%
for doc in modificar.find({'disponible': True}):
    print('disponible', doc['disponible'])
# Out:
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True
# disponible True

# %%
# Bulk write
operations = [
    UpdateOne({'Título': 'La ciudad Verde'}, {'$set':{'Stock': 6}}),
]
modificar.bulk_write(operations)
# Out:
# BulkWriteResult({'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 1, 'nModified': 1, 'nRemoved': 0, 'upserted': []}, acknowledged=True)
